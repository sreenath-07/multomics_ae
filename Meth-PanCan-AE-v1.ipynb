# %%
# TCGA_abbr = {
#     "LAML": "leukemia",
#     "ACC" : "adrenocortical",
#     "BLCA": "bladder",
#     "LGG" : "brain",
#     "BRCA": "breast",
#     "CESC": "cervical",
#     "CHOL": "cholangiocarcinoma",
#     "LCML": "Chronic myelogenous leukemia",
#     "COAD": "Colon adenocarcinoma",
#     "CNTL": "Controls",
#     "ESCA": "Esophageal carcinoma",
#     "FPPP": "FFPE pilot phase II",
#     "GBM":  "Glioblastoma multiforme",
#     "HNSC": "Head",
#     "KICH": "Kidney chromophobe",
#     "KIRC": "Kidney renal clear cell carcinoma",
#     "KIRP": "Kidney renal papillary cell carcinoma",
#     "LIHC": "Liver hepatocellular carcinoma",
#     "LUAD": "Lung adenocarcinoma",
#     "LUSC": "Lung squamous cell carcinoma",
#     "DLBC": "Lymphoid neoplasm diffuse large b-cell lymphoma",
#     "MESO": "Mesothelioma",
#     "MISC": "Miscellaneous",
#     "OV" :  "Ovarian serous cystadenocarcinoma",
#     "PAAD": "Pancreatic adenocarcinoma",
#     "PCPG": "Pheochromocytoma and paraganglioma",
#     "PRAD": "Prostate adenocarcinoma",
#     "READ": "Rectum adenocarcinoma",
#     "SARC": "Sarcoma",
#     "SKCM": "Skin cutaneous melanoma",
#     "STAD": "Stomach adenocarcinoma",
#     "TGCT": "Testicular germ cell tumors",
#     "THYM": "Thymoma",
#     "THCA": "Thyroid carcinoma",
#     "UCS" : "Uterine carcinosarcoma",
#     "UCEC": "Uterine corpus endometrial carcinoma",
#     "UVM" : "Uveal melanoma"
#     }

# %% [markdown]
# # Applying Autoencoders to DNA Methylation data from TCGA (MLB Lab)

# %%
import os
repo_path = r"Y:\qiu-lab\Bridget\data\meth\methylation_raw"
# ignore_list = ["assemble.py","assemble2.py",assembled.csv]

cancer_paths = []
for directory in os.listdir(repo_path):
    path = os.path.join(repo_path, directory)
    if os.path.isdir(path) and directory!="LOGS":  
        cancer_paths.append(path)
# cancer_paths

# %%
from time import sleep
from random import random
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import pandas as pd
import glob
from time import time

# custom task that will sleep for a variable amount of time
def create_cancer_df(cancer):
    start = time()
    cancer_df_list = []

    #Parse the Metadata file
    cancer_name = cancer.split("\\")[-1] #Separating the cancer name from the entire path
    metadata_file = f"{cancer}\\manifest_me_{cancer_name}.txt"
    metadata = pd.read_csv(metadata_file, sep='\t')
    #The TCGA barcode is towards the tail end of the "Filename" split with "." 
    metadata["tcga_barcode"] = [patient.rstrip("gdc_hg38.txt").split(".")[-1] for patient in metadata["filename"]]
    metadata = metadata[["id","tcga_barcode"]]
    metadata.set_index('id',inplace=True)

    #Going through every patient directory
    for patient_directory in os.listdir(cancer):
        patient_path = os.path.join(cancer, patient_directory)
        if os.path.isdir(patient_path): 
            #Parsing the important counts file inside the directory
            methylation_data_path = f"{patient_path}\\*HumanMethylation450*" #The data file contains the key word
            methylation_data_file =  glob.glob(methylation_data_path) #Finding files that match that pattern
            patient_df = pd.read_csv(methylation_data_file[0], sep='\t',index_col=0) #Taking the first file in the list that matches -> Assuming only one does

            #Retrieving tcga barcode from metadata file
            tcga_barcode = metadata[metadata.index==patient_directory]["tcga_barcode"].tolist()[0]
            patient_df.rename(columns={"Beta_value": tcga_barcode},inplace=True) #Inserting the patient barcode into the data frame
            cancer_df_list.append(patient_df)

    cancer_df = pd.concat(cancer_df_list,axis=1)   
    end = time()
    print(f"Time for cancer: {cancer_name} = {end-start}")
    return cancer_df

pancancer_df_list = []
with ThreadPoolExecutor(8) as executor:
    # execute tasks concurrently and process results in order
    for result in executor.map(create_cancer_df, cancer_paths):
        pancancer_df_list.append(result)
pancaner_df = pd.concat(pancancer_df_list,axis=1)

# %%
pancaner_df.dropna(how='all',axis=1,inplace=True) #Removing columns with all nan rows
pancaner_df.dropna(how='all',axis=0,inplace=True) #Removing rows with all nan columns
# import pickle
# with open("pancan_methylation.pickle","wb") as pikd:
#     pickle.dump(pancaner_df,pikd)

# %%
# import joblib
# joblib.dump(pancaner_df, 'pancan_methylation.pkl')

# %%
# pancaner_df = pancaner_df.T

# %%
import joblib
pancaner_df = joblib.load('pancan_methylation.pkl')
pancaner_df.shape

# %%
pancaner_df.head()

# %%
# merged_df.to_csv("pancan_methylation.csv.gz", compression="gzip")
# # merged_df_2 = pd.read_csv("pancan_methylation.csv.gz", index_col=0, compression="gzip") 
# # merged_df_2.head()

# %% [markdown]
# ### 2. Removing all Nan

# %%
# # pan_can_meth_df.replace("NA", np.nan, inplace=True)
# pan_can_meth_df.dropna(how='all',axis=1,inplace=True) #Removing columns with all nan rows
# pan_can_meth_df.dropna(how='all',axis=0,inplace=True) #Removing rows with all nan columns
# start_filling = time()
# pan_can_meth_df.fillna(pan_can_meth_df.mean(), inplace=True)
# end_filling = time()
# print(f"Time: {end_filling - start_filling}")
# print(pan_can_meth_df.shape)

# %%
meth_df_path = r"Y:\qiu-lab\Bridget\data\meth\meth_ALLsamp_notnacpgs_raw.pkl"
import joblib
pancaner_df = joblib.load(meth_df_path)
pancaner_df.shape
# Out:
# (9756, 396065)

# %% [markdown]
# ### 3. Filling nan cells with mean using numpy

# %%
## Removing nan
import numpy as np 
import pandas as pd

pancan_numpy = pancaner_df.to_numpy()
print(pancaner_df.isnull().sum().sum())
col_mean = np.nanmean(pancan_numpy, axis=0)
#Find indices that you need to replace
inds = np.where(np.isnan(pancan_numpy))
#Place column means in the indices. Align the arrays using take
pancan_numpy[inds] = np.take(col_mean, inds[1])

pancancer_meth_df = pd.DataFrame(pancan_numpy,columns = pancaner_df.columns, index = pancaner_df.index)
pancancer_meth_df.isnull().sum().sum()
# Out:
# 4119767
# 0

# %% [markdown]
# ### 4. Splitting into dataframe for each chromosome

# %%
reference_path = r"Y:\qiu-lab\Bridget\data\meth\methylation_raw\methylation_reference.txt"
reference_df = pd.read_csv(reference_path, sep = "\t")
#Remove those rows that don't have a corresponding column in the pancancer dataframe (Maybe they were removed during preprocessing)
pancan_allfeatures = pancaner_df.columns.tolist()
reference_df = reference_df[reference_df["Composite Element REF"].isin(pancan_allfeatures)]
reference_df.shape
# Out:
# (396065, 10)

# %%
# Creating a dictionary with all the Chromsomes and their respective Methylation Probes
chr_dict = reference_df.groupby("Chromosome")["Composite Element REF"].apply(list).to_dict()
del chr_dict['*']
del chr_dict['chrY']
chr_dict.keys()
# Out:
# dict_keys(['chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14', 'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr2', 'chr20', 'chr21', 'chr22', 'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9', 'chrX'])

# %%
pancancer_meth_list = []
for chromsome, feature_list in chr_dict.items():
    print(chromsome)
    print(len(feature_list))
    new_df = pancancer_meth_df[feature_list]
    new_df = new_df.astype('float16')
    print("Done conveting to float16")
    pancancer_meth_list.append(new_df)
# Out:
# chr1
# 38021
# Done conveting to float16
# chr10
# 19783
# Done conveting to float16
# chr11
# 23600
# Done conveting to float16
# chr12
# 19810
# Done conveting to float16
# chr13
# 9745
# Done conveting to float16
# chr14
# 12340
# Done conveting to float16
# chr15
# 12446
# Done conveting to float16
# chr16
# 17962
# Done conveting to float16
# chr17
# 23404
# Done conveting to float16
# chr18
# 5008
# Done conveting to float16
# chr19
# 21049
# Done conveting to float16
# chr2
# 28024
# Done conveting to float16
# chr20
# 8649
# Done conveting to float16
# chr21
# 3225
# Done conveting to float16
# chr22
# 6994
# Done conveting to float16
# chr3
# 20139
# Done conveting to float16
# chr4
# 15927
# Done conveting to float16
# chr5
# 19640
# Done conveting to float16
# chr6
# 29181
# Done conveting to float16
# chr7
# 24026
# Done conveting to float16
# chr8
# 16464
# Done conveting to float16
# chr9
# 8031
# Done conveting to float16
# chrX
# 9706
# Done conveting to float16

# %%
## Saving the list of chromosome dataframe
import joblib
joblib.dump(pancancer_meth_list, "pancancer_meth_chr_nonna_fillnamean.pkl")

with open ("pancancer_meth_chr_nonna_fillnamean_reference.txt","w+") as outfile:
    outfile.write(str(chr_dict.keys()))

# %% [markdown]
# ### 5. Building a Vanilla Autoencoder

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt

import tensorflow as tf
from numpy.random import seed
from sklearn.model_selection import train_test_split
from keras.layers import Input, Dense, Concatenate
from keras.models import Model
from keras import backend as K #For explicitly \adjusting the learning rate

# %% [markdown]
# ### 5.1. Splitting the Data into test and training

# %%
X_train, X_val = train_test_split(pancancer_meth_list[0], test_size=0.2, random_state = seed(77))
#Since the samples will be split similarly across all chromosomes, we shall match the indices for 
# X_train and X_val across all chr
training_indices = X_train.index
validation_indices = X_val.index

X_train_list = []
X_val_list = []
for chrom_df in pancancer_meth_list:
    X_train_list.append(chrom_df.loc[training_indices])
    X_val_list.append(chrom_df.loc[validation_indices])

# %% [markdown]
# ### 5.2. Autencoder Architecture

# %%
ncol_list = []
for df in pancancer_meth_list:
    ncol_list.append(df.shape[1])
number_of_chromosomes = len(pancancer_meth_list)
encoding_dim = 100 #Nodes in Bottleneck layer

## Encoder Layers
encoded1_list = []
input_dim_list = []
for ncol in ncol_list:
    input_dim_i = Input(shape = (ncol, ))
    input_dim_list.append(input_dim_i)
    encoded1_list.append(Dense(256, activation = 'relu')(input_dim_i))

encoded1 = Concatenate(axis=1)(encoded1_list)
encoded2 = Dense(500, activation = 'relu')(encoded1)
encoded3 = Dense(encoding_dim, activation = 'relu')(encoded2)

## Decoder Layers
decoded3 = Dense(500, activation = 'relu')(encoded3)
decoded2 = Dense(256*number_of_chromosomes, activation = 'relu')(decoded3)

### Final layer
reconstructured_inputs = []
for i in range(0,number_of_chromosomes):
    start = 256*(i)
    end = 256*i+1
    decoded2_i = decoded2[:,start:end] #Splicing the tensor back to 256*23 tensors
    reconstructured_inputs.append(Dense(ncol_list[i], activation = 'sigmoid')(decoded2_i))

# %%
autoencoder = Model(inputs = input_dim_list, outputs = reconstructured_inputs)
# Compile the Model
autoencoder.compile(optimizer = 'adam', loss = 'mean_squared_error')#Should try Pseudo-Heuber Loss, Binary Crossentropy 
#adam - stochastic gradient descent algorithm
K.set_value(autoencoder.optimizer.learning_rate, 0.0001) #Setting the learning rate to 10^-3

autoencoder.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_24 (InputLayer)          [(None, 38021)]      0           []
#
#  input_25 (InputLayer)          [(None, 19783)]      0           []
#
#  input_26 (InputLayer)          [(None, 23600)]      0           []
#
#  input_27 (InputLayer)          [(None, 19810)]      0           []
#
#  input_28 (InputLayer)          [(None, 9745)]       0           []
#
#  input_29 (InputLayer)          [(None, 12340)]      0           []
#
#  input_30 (InputLayer)          [(None, 12446)]      0           []
#
#  input_31 (InputLayer)          [(None, 17962)]      0           []
#
#  input_32 (InputLayer)          [(None, 23404)]      0           []
#
#  input_33 (InputLayer)          [(None, 5008)]       0           []
#
#  input_34 (InputLayer)          [(None, 21049)]      0           []
#
#  input_35 (InputLayer)          [(None, 28024)]      0           []
#
#  input_36 (InputLayer)          [(None, 8649)]       0           []
#
#  input_37 (InputLayer)          [(None, 3225)]       0           []
#
#  input_38 (InputLayer)          [(None, 6994)]       0           []
#
#  input_39 (InputLayer)          [(None, 20139)]      0           []
#
#  input_40 (InputLayer)          [(None, 15927)]      0           []
#
#  input_41 (InputLayer)          [(None, 19640)]      0           []
#
#  input_42 (InputLayer)          [(None, 29181)]      0           []
#
#  input_43 (InputLayer)          [(None, 24026)]      0           []
#
#  input_44 (InputLayer)          [(None, 16464)]      0           []
#
#  input_45 (InputLayer)          [(None, 8031)]       0           []
#
#  input_46 (InputLayer)          [(None, 9706)]       0           []
#
#  dense_50 (Dense)               (None, 256)          9733632     ['input_24[0][0]']
#
#  dense_51 (Dense)               (None, 256)          5064704     ['input_25[0][0]']
#
#  dense_52 (Dense)               (None, 256)          6041856     ['input_26[0][0]']
#
#  dense_53 (Dense)               (None, 256)          5071616     ['input_27[0][0]']
#
#  dense_54 (Dense)               (None, 256)          2494976     ['input_28[0][0]']
#
#  dense_55 (Dense)               (None, 256)          3159296     ['input_29[0][0]']
#
#  dense_56 (Dense)               (None, 256)          3186432     ['input_30[0][0]']
#
#  dense_57 (Dense)               (None, 256)          4598528     ['input_31[0][0]']
#
#  dense_58 (Dense)               (None, 256)          5991680     ['input_32[0][0]']
#
#  dense_59 (Dense)               (None, 256)          1282304     ['input_33[0][0]']
#
#  dense_60 (Dense)               (None, 256)          5388800     ['input_34[0][0]']
#
#  dense_61 (Dense)               (None, 256)          7174400     ['input_35[0][0]']
#
#  dense_62 (Dense)               (None, 256)          2214400     ['input_36[0][0]']
#
#  dense_63 (Dense)               (None, 256)          825856      ['input_37[0][0]']
#
#  dense_64 (Dense)               (None, 256)          1790720     ['input_38[0][0]']
#
#  dense_65 (Dense)               (None, 256)          5155840     ['input_39[0][0]']
#
#  dense_66 (Dense)               (None, 256)          4077568     ['input_40[0][0]']
#
#  dense_67 (Dense)               (None, 256)          5028096     ['input_41[0][0]']
#
#  dense_68 (Dense)               (None, 256)          7470592     ['input_42[0][0]']
#
#  dense_69 (Dense)               (None, 256)          6150912     ['input_43[0][0]']
#
#  dense_70 (Dense)               (None, 256)          4215040     ['input_44[0][0]']
#
#  dense_71 (Dense)               (None, 256)          2056192     ['input_45[0][0]']
#
#  dense_72 (Dense)               (None, 256)          2484992     ['input_46[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5888)         0           ['dense_50[0][0]',
#                                                                   'dense_51[0][0]',
#                                                                   'dense_52[0][0]',
#                                                                   'dense_53[0][0]',
#                                                                   'dense_54[0][0]',
#                                                                   'dense_55[0][0]',
#                                                                   'dense_56[0][0]',
#                                                                   'dense_57[0][0]',
#                                                                   'dense_58[0][0]',
#                                                                   'dense_59[0][0]',
#                                                                   'dense_60[0][0]',
#                                                                   'dense_61[0][0]',
#                                                                   'dense_62[0][0]',
#                                                                   'dense_63[0][0]',
#                                                                   'dense_64[0][0]',
#                                                                   'dense_65[0][0]',
#                                                                   'dense_66[0][0]',
#                                                                   'dense_67[0][0]',
#                                                                   'dense_68[0][0]',
#                                                                   'dense_69[0][0]',
#                                                                   'dense_70[0][0]',
#                                                                   'dense_71[0][0]',
#                                                                   'dense_72[0][0]']
#
#  dense_73 (Dense)               (None, 500)          2944500     ['concatenate_1[0][0]']
#
#  dense_74 (Dense)               (None, 100)          50100       ['dense_73[0][0]']
#
#  dense_75 (Dense)               (None, 500)          50500       ['dense_74[0][0]']
#
#  dense_76 (Dense)               (None, 5888)         2949888     ['dense_75[0][0]']
#
#  tf.__operators__.getitem_23 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_24 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_25 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_26 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_27 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_28 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_29 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_30 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_31 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_32 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_33 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_34 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_35 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_36 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_37 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_38 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_39 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_40 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_41 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_42 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_43 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_44 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_45 (S  (None, 1)           0           ['dense_76[0][0]']
#  licingOpLambda)
#
#  dense_77 (Dense)               (None, 38021)        76042       ['tf.__operators__.getitem_23[0][
#                                                                  0]']
#
#  dense_78 (Dense)               (None, 19783)        39566       ['tf.__operators__.getitem_24[0][
#                                                                  0]']
#
#  dense_79 (Dense)               (None, 23600)        47200       ['tf.__operators__.getitem_25[0][
#                                                                  0]']
#
#  dense_80 (Dense)               (None, 19810)        39620       ['tf.__operators__.getitem_26[0][
#                                                                  0]']
#
#  dense_81 (Dense)               (None, 9745)         19490       ['tf.__operators__.getitem_27[0][
#                                                                  0]']
#
#  dense_82 (Dense)               (None, 12340)        24680       ['tf.__operators__.getitem_28[0][
#                                                                  0]']
#
#  dense_83 (Dense)               (None, 12446)        24892       ['tf.__operators__.getitem_29[0][
#                                                                  0]']
#
#  dense_84 (Dense)               (None, 17962)        35924       ['tf.__operators__.getitem_30[0][
#                                                                  0]']
#
#  dense_85 (Dense)               (None, 23404)        46808       ['tf.__operators__.getitem_31[0][
#                                                                  0]']
#
#  dense_86 (Dense)               (None, 5008)         10016       ['tf.__operators__.getitem_32[0][
#                                                                  0]']
#
#  dense_87 (Dense)               (None, 21049)        42098       ['tf.__operators__.getitem_33[0][
#                                                                  0]']
#
#  dense_88 (Dense)               (None, 28024)        56048       ['tf.__operators__.getitem_34[0][
#                                                                  0]']
#
#  dense_89 (Dense)               (None, 8649)         17298       ['tf.__operators__.getitem_35[0][
#                                                                  0]']
#
#  dense_90 (Dense)               (None, 3225)         6450        ['tf.__operators__.getitem_36[0][
#                                                                  0]']
#
#  dense_91 (Dense)               (None, 6994)         13988       ['tf.__operators__.getitem_37[0][
#                                                                  0]']
#
#  dense_92 (Dense)               (None, 20139)        40278       ['tf.__operators__.getitem_38[0][
#                                                                  0]']
#
#  dense_93 (Dense)               (None, 15927)        31854       ['tf.__operators__.getitem_39[0][
#                                                                  0]']
#
#  dense_94 (Dense)               (None, 19640)        39280       ['tf.__operators__.getitem_40[0][
#                                                                  0]']
#
#  dense_95 (Dense)               (None, 29181)        58362       ['tf.__operators__.getitem_41[0][
#                                                                  0]']
#
#  dense_96 (Dense)               (None, 24026)        48052       ['tf.__operators__.getitem_42[0][
#                                                                  0]']
#
#  dense_97 (Dense)               (None, 16464)        32928       ['tf.__operators__.getitem_43[0][
#                                                                  0]']
#
#  dense_98 (Dense)               (None, 8031)         16062       ['tf.__operators__.getitem_44[0][
#                                                                  0]']
#
#  dense_99 (Dense)               (None, 9706)         19412       ['tf.__operators__.getitem_45[0][
#                                                                  0]']
#
# ==================================================================================================
# Total params: 107,439,768
# Trainable params: 107,439,768
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#Implementing Early Stopping
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# %%
#Obtain the reduced data
encoder = Model(inputs = input_dim_list, outputs = encoded3)
encoded_input = Input(shape = (encoding_dim, ))

encoded_train = pd.DataFrame(encoder.predict(pancancer_meth_list), index=pancancer_meth_list[0].index) #Maintain Index for Mapping to cancer type 
encoded_train = encoded_train.add_prefix('feature_')
encoded_train.shape
# Out:
# (9756, 100)

# %%
#output dataset
shape_before_removing_nan = encoded_train.shape
encoded_train.replace(0, np.nan, inplace=True) #Converting all the zero's to nan to use nan command
encoded_train.dropna(how='all',axis=1, inplace=True) #Removing columns with all nan rows
encoded_train.dropna(how='all',axis=0, inplace=True) #Removing rows with all nan columns
encoded_train.replace(np.nan, 0, inplace=True) #Converting all the nan's to zero to be compatible with t-SNE
print(shape_before_removing_nan, encoded_train.shape)

encoded_train.to_csv("Meth_AE_v1.csv", index=True)
# encoded_train = pd.read_csv("Meth_AE_v1.csv",index_col=[0,1,2,3,4])
# Out:
# (9756, 100) (9756, 64)

# %%
#Scaling these features to -1,1 range for applying tsne
from sklearn.preprocessing import MinMaxScaler
feature_list = encoded_train.columns.tolist()
scaler = MinMaxScaler(feature_range=(0,1))
encoded_train[feature_list] = scaler.fit_transform(encoded_train[feature_list])

# %%
encoded_train.head()
# Out:
#                                                                                                                            feature_0  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.474607
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.552040
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.361155
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.590417
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.570545
#
#                                                                                                                            feature_2  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.423551
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.502754
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.185393
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.402349
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.425510
#
#                                                                                                                            feature_4  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.455122
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.726408
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   0.625676
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\
01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.509224
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.657337
#
#                                                                                                                            feature_95  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.524341
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.705609
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.722983
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.588755
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.690141
#
#                                                                                                                            feature_98  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.370756
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.667947
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.578920
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.566057
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.630435
#
#                                                                                                                            feature_99
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.449654
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.727417
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.617908
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.609464
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...    0.679509
#
# [5 rows x 64 columns]

# %% [markdown]
# ### 6. Dimension Reduction and Cluster Visualization using t-SNE

# %% [markdown]
# perplexity parameter can be changed based on the input datatset - dataset with larger number of variables requires larger perplexity set this value between 5 and 50 (sklearn documentation) verbose=1 displays run time messages set n_iter sufficiently high to resolve the well stabilized cluster get embeddings

# %%
# Perform t-SNE on AE encoded_features
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, init='pca', random_state=0, perplexity=40, learning_rate=300, n_iter=400, verbose=1)
#TSNE(n_components=2, perplexity=105, n_iter=1000, verbose=1).fit_transform(encoded_train)
tsne_out = tsne.fit_transform(encoded_train)
tsne_components = pd.DataFrame(tsne_out, index =encoded_train.index ) #Maintain Index
# Out:
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 9756 samples in 0.001s...
# [t-SNE] Computed neighbors for 9756 samples in 12.599s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9756
# [t-SNE] Computed conditional probabilities for sample 2000 / 9756
# [t-SNE] Computed conditional probabilities for sample 3000 / 9756
# [t-SNE] Computed conditional probabilities for sample 4000 / 9756
# [t-SNE] Computed conditional probabilities for sample 5000 / 9756
# [t-SNE] Computed conditional probabilities for sample 6000 / 9756
# [t-SNE] Computed conditional probabilities for sample 7000 / 9756
# [t-SNE] Computed conditional probabilities for sample 8000 / 9756
# [t-SNE] Computed conditional probabilities for sample 9000 / 9756
# [t-SNE] Computed conditional probabilities for sample 9756 / 9756
# [t-SNE] Mean sigma: 0.157354
# C:\Users\ssrikrishnan6\Anaconda3\envs\metalearning\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.551117
# [t-SNE] KL divergence after 400 iterations: 1.998454

# %%
# Perform t-SNE on AE encoded_features
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0, perplexity=100, verbose=1)
tsne_out = tsne.fit_transform(encoded_train)
tsne_components = pd.DataFrame(tsne_out, index =encoded_train.index ) #Maintain Index
# Out:
# C:\Users\ssrikrishnan6\Anaconda3\envs\metalearning\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\ssrikrishnan6\Anaconda3\envs\metalearning\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 9756 samples in 0.002s...
# [t-SNE] Computed neighbors for 9756 samples in 13.076s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9756
# [t-SNE] Computed conditional probabilities for sample 2000 / 9756
# [t-SNE] Computed conditional probabilities for sample 3000 / 9756
# [t-SNE] Computed conditional probabilities for sample 4000 / 9756
# [t-SNE] Computed conditional probabilities for sample 5000 / 9756
# [t-SNE] Computed conditional probabilities for sample 6000 / 9756
# [t-SNE] Computed conditional probabilities for sample 7000 / 9756
# [t-SNE] Computed conditional probabilities for sample 8000 / 9756
# [t-SNE] Computed conditional probabilities for sample 9000 / 9756
# [t-SNE] Computed conditional probabilities for sample 9756 / 9756
# [t-SNE] Mean sigma: 0.196983
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.386414
# [t-SNE] KL divergence after 1000 iterations: 1.447459

# %%
tsne_components.head()
# Out:
#                                                                                                                                    0  \
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   9.716876
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...   3.553392
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  44.419983
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad... -10.130936
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  -1.912631
#
#                                                                                                                                    1
# patient      sample           sample_type aliquot                      file
# TCGA-OR-A5J4 TCGA-OR-A5J4-01A 01A         TCGA-OR-A5J4-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad... -34.206795
# TCGA-OR-A5KO TCGA-OR-A5KO-01A 01A         TCGA-OR-A5KO-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  36.338497
# TCGA-OR-A5J9 TCGA-OR-A5J9-01A 01A         TCGA-OR-A5J9-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  24.706619
# TCGA-OR-A5K6 TCGA-OR-A5K6-01A 01A         TCGA-OR-A5K6-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  15.436491
# TCGA-OR-A5JJ TCGA-OR-A5JJ-01A 01A         TCGA-OR-A5JJ-01A-11D-A29J-05 Y:\qiu-lab\Bridget\data\meth\methylation_raw\ad...  29.983887

# %% [markdown]
# ### 7. Mapping samples to cancer type

# %%
import pandas as pd
patient_metadata = pd.read_csv(r"C:\Users\ssrikrishnan6\ae_integration\info_all_ex.txt", sep = "\t")
patient_metadata = patient_metadata[[ 'cases.0.samples.0.portions.0.analytes.0.aliquots.0.submitter_id','cases.0.project.project_id','cases.0.samples.0.sample_type']] #tolist()
patient_metadata.rename(columns={'cases.0.project.project_id': "cancer_type", "cases.0.samples.0.portions.0.analytes.0.aliquots.0.submitter_id":"tcga_id"},inplace=True)
patient_metadata.set_index("tcga_id", inplace=True)

new_patient_indices = []
for index in patient_metadata.index:
    new_patient_indices.append("-".join(index.split("-")[:-3]))
patient_metadata.index = new_patient_indices

# %%
#Parsing the index to extract TCGA Barcode
new_indices = []
for index in tsne_components.index:
    new_indices.append(index[1])

new_tsne_components = tsne_components.copy()
new_tsne_components.index = new_indices

#Merging based on tcga_id
grouped_tsne = pd.merge(new_tsne_components , patient_metadata['cancer_type'] , left_index=True, right_index=True)

grouped_tsne.head()
grouped_tsne.to_csv("tsne_meth_ae_v1.csv")

# %%
# grouped_tsne = pd.merge(new_tsne_components , patient_metadata['cancer_type'], left_index=True, right_index=True)
grouped_tsne.shape
# Out:
# (9151, 3)

# %%
temp_list = list(set(new_tsne_components.index.tolist()) - set(patient_metadata['cancer_type'].index.tolist()))
len(temp_list)
# Out:
# 655

# %% [markdown]
# ## 8. Evaluating the PanCancer Clustering

# %%
import matplotlib.pyplot as plt
import seaborn
seaborn.set(style='ticks')

cancer_types = grouped_tsne['cancer_type'].tolist()
cancer_types = list(set(cancer_types))

seaborn.relplot(data=grouped_tsne, x=0, y=1, hue='cancer_type', hue_order=cancer_types, aspect=1.61)
plt.show()

# %% [markdown]
# Relplot = A figure-level function for visualizing statistical relationships using two common approaches: scatter plots and line plots. relplot() combines a FacetGrid with one of two axes-level functions: scatterplot() (with kind="scatter" ; the default)

# %%
lung_cancer_types = ["TCGA-LUAD","TCGA-LUSC"] 
lung_cancer_df = grouped_tsne[grouped_tsne['cancer_type'].isin(lung_cancer_types)]

seaborn.relplot(data=lung_cancer_df, x=0, y=1, hue='cancer_type', hue_order=lung_cancer_types, aspect=1.61)
plt.show()

# %%
lung_breast_cancer_types = ["TCGA-LUAD","TCGA-BRCA"] 
lung_breast_cancer_df = grouped_tsne[grouped_tsne['cancer_type'].isin(lung_breast_cancer_types)]

seaborn.relplot(data=lung_breast_cancer_df, x=0, y=1, hue='cancer_type', hue_order=lung_breast_cancer_types, aspect=1.61)
plt.show()

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
# sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 12331266130193884624
# xla_global_id: -1
# ]

# %%
# %conda list
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
